# %%
import pandas as pd

# %%
data=pd.read_csv(filepath_or_buffer =  '../capstone 1/DOB_Permit_Issuance.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3747452 entries, 0 to 3747451
# Data columns (total 60 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   BOROUGH                           object
#  1   Bin #                             object
#  2   House #                           object
#  3   Street Name                       object
#  4   Job #                             int64
#  5   Job doc. #                        int64
#  6   Job Type                          object
#  7   Self_Cert                         object
#  8   Block                             object
#  9   Lot                               object
#  10  Community Board                   object
#  11  Zip Code                          float64
#  12  Bldg Type                         float64
#  13  Residential                       object
#  14  Special District 1                object
#  15  Special District 2                object
# ...

# %%
data.columns = data.columns.str.replace("'"," ")

# %%
pd.set_option('display.max_columns', None)
# Out:
#                BOROUGH    Bin # House #      Street Name      Job #  \
# 0            MANHATTAN  1077287    1230       6TH AVENUE  123725807
# 1        STATEN ISLAND  5113169     715    OCEAN TERRACE  500876037
# 2             BROOKLYN  3253458    9952            3 AVE  321963014
# 3             BROOKLYN  3117942     179      LOTT STREET  322006618
# 4             BROOKLYN  3210296    2917        AVENUE  N  321996970
# ...                ...      ...     ...              ...        ...
# 3747447         QUEENS  4205475  107-24       120 STREET  421930101
# 3747448       BROOKLYN  3055424    1010   BEDFORD AVENUE  310155925
# 3747449       BROOKLYN  3127666     119  WEBSTER  AVENUE  320267386
# 3747450         QUEENS  4057949   73-17         52 COURT  440626798
# 3747451       BROOKLYN  3008508      96      KING STREET  320911652
#
#          Job doc. # Job Type Self_Cert Block Lot Community Board  Zip Code  \
# ...

# %%
data[(data['House #'] == "144-21") & (data['Street Name'] == "LAKEWOOD AVENUE")]
# Out:
#         BOROUGH    Bin # House #      Street Name      Job #  Job doc. #  \
# 1116040  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 1411584  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 2519390  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 2959673  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3064446  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3526723  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3526793  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3526794  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3526796  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
# 3557811  QUEENS  4596265  144-21  LAKEWOOD AVENUE  421056252           1
#
#         Job Type Self_Cert  Block    Lot Community Board  Zip Code  Bldg Type  \
# 1116040       NB         N  10078     40             412   11435.0        1.0
# ...

# %%
names = data['Permittee s Last Name'].value_counts()
names[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Permittee s Last Name'].value_counts()
# Out:
# SINGH            57474
# LEE              21788
# LEVINE           21344
# MARTINEZ         20479
# WHITE            20050
#                  ...
# BURAY                1
# MEKULI               1
# CANRIDI              1
# PIAGIOULIATOS        1
# FRUGME               1
# Name: Permittee s Last Name, Length: 91828, dtype: int64

# %%
data_singh = data[data['Permittee s Last Name']=='SINGH']

# %%
data_singh_types = data_singh['Job Type'].value_counts()
data_singh_types.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data_lee = data[data['Permittee s Last Name']=='LEE']

# %%
data_lee_types = data_lee['Job Type'].value_counts()
data_lee_types.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data_levine = data[data['Permittee s Last Name']=='LEVINE']

# %%
data_levine_types = data_levine['Job Type'].value_counts()
data_levine_types.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data_martinez = data[data['Permittee s Last Name']=='MARTINEZ']

# %%
data_martinez_types = data_martinez['Job Type'].value_counts()
data_martinez_types.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#JOb Type = A2 and top 10 people last names
data_names_top10 = (data['Permittee s Last Name'].value_counts().index.to_list())[:10]
data_names_top10
# Out:
# ['SINGH',
#  'LEE',
#  'LEVINE',
#  'MARTINEZ',
#  'WHITE',
#  'BROWN',
#  'HARRINGTON',
#  'DOWNES',
#  'WEINTRAUB',
#  'WAGNER']

# %%
job_types = ['A2', 'A1', 'NB', 'DM']

# %%
df_data_names_top10=data[(data['Permittee s Last Name'].isin(data_names_top10)) & (data['Job Type'].isin(job_types))]

# %%
df_data_names_top10['Permittee s Last Name'].value_counts()
# Out:
# LEVINE        21289
# SINGH         21011
# LEE           19913
# WHITE         19640
# MARTINEZ      18575
# WEINTRAUB     11432
# WAGNER        10868
# BROWN          7277
# HARRINGTON      430
# DOWNES           43
# Name: Permittee s Last Name, dtype: int64

# %%
df_data_names_top10['Job Type'].value_counts()
# Out:
# A2    95100
# NB    17459
# A1    16212
# DM     1707
# Name: Job Type, dtype: int64

# %%
last_names = data_names_top10
job_types = ['A2', 'A1', 'NB', 'DM']

# %%
df_data_names_top10_grouped = df_data_names_top10.groupby(['Permittee s Last Name', 'Job Type'], as_index=False)

# %%
df11 = pd.DataFrame(df_data_names_top10_grouped.size())

# %%
df11 = df11.set_index(['Permittee s Last Name', 'Job Type'])
# df11 = df11.set_index(['Permittee s Last Name'])

# %%
df11
# Out:
#                                  size
# Permittee s Last Name Job Type
# BROWN                 A1         1788
#                       A2         3418
#                       DM          589
#                       NB         1482
# DOWNES                A1            2
#                       A2           41
# HARRINGTON            A1          102
#                       A2          318
#                       DM            1
#                       NB            9
# LEE                   A1         2750
#                       A2        13828
#                       DM          190
#                       NB         3145
# LEVINE                A1          529
#                       A2        19998
#                       DM          129
#                       NB          633
# MARTINEZ              A1          943
#                       A2        16214
#                       DM          109
#                       NB         1309
# SINGH                 A1         3867
# ...

# %%
df11.unstack().plot(kind='barh', figsize= (10,20), width=1)
# Out:
# <AxesSubplot:ylabel='Permittee s Last Name'>

# %%
df11.unstack().plot(kind='bar', figsize= (20,10))
# Out:
# <AxesSubplot:xlabel='Permittee s Last Name'>

# %%
df11.sort_values('size').plot(kind='bar', figsize= (15,10))
# Out:
# <AxesSubplot:xlabel='Permittee s Last Name,Job Type'>

# %%
last_names = data_names_top10
job_types = ['A2', 'A1', 'NB', 'DM']
# Out:
#    Permittee s Last Name Job Type   size
# 0                  BROWN       A1   1788
# 1                  BROWN       A2   3418
# 2                  BROWN       DM    589
# 3                  BROWN       NB   1482
# 4                 DOWNES       A1      2
# 5                 DOWNES       A2     41
# 6             HARRINGTON       A1    102
# 7             HARRINGTON       A2    318
# 8             HARRINGTON       DM      1
# 9             HARRINGTON       NB      9
# 10                   LEE       A1   2750
# 11                   LEE       A2  13828
# 12                   LEE       DM    190
# 13                   LEE       NB   3145
# 14                LEVINE       A1    529
# 15                LEVINE       A2  19998
# 16                LEVINE       DM    129
# 17                LEVINE       NB    633
# 18              MARTINEZ       A1    943
# 19              MARTINEZ       A2  16214
# 20              MARTINEZ       DM    109
# 21              MARTINEZ       NB   1309
# ...

# %%
data1.to_csv('NY_Permitdata__cleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-a076c2606c4a> in <module>
# ----> 1 data1.to_csv('NY_Permitdata__cleaned.csv', index=False)
#
# NameError: name 'data1' is not defined
