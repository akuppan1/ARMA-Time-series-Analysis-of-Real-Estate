# %%
import pandas as pd

# %%
data=pd.read_csv('DOB_Permit_Issuance.csv')
# Out:
# C:\Users\booos\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (1,8,9,10,15,31,33,34,35,36,51,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#          BOROUGH    Bin # House #    Street Name      Job #  Job doc. #  \
# 0      MANHATTAN  1077287    1230     6TH AVENUE  123725807           1
# 1  STATEN ISLAND  5113169     715  OCEAN TERRACE  500876037           1
# 2       BROOKLYN  3253458    9952          3 AVE  321963014           1
# 3       BROOKLYN  3117942     179    LOTT STREET  322006618           1
# 4       BROOKLYN  3210296    2917      AVENUE  N  321996970           1
#
#   Job Type Self_Cert Block Lot  ... Owner’s House State  \
# 0       A2         Y  1264   5  ...                  NY
# 1       A2         Y   683   1  ...                  NY
# 2       DM         N  6133  56  ...                  NY
# 3       DM         N  5136  58  ...                  NY
# 4       DM         N  7665   4  ...                  NY
#
#    Owner’s House Zip Code  Owner's Phone #           DOBRunDate PERMIT_SI_NO  \
# 0                   10111      2.12715e+09  12/12/2020 00:00:00      3554580
# ...

# %%
data1 = data[['BOROUGH','Job Type','DOBRunDate']]

# %%
is_NaN = data1.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = data1[row_has_NaN]
print(rows_with_NaN)
# Out:
#         BOROUGH Job Type DOBRunDate
# 81322  BROOKLYN       A2        NaN

# %%
#There is only 1 row with NaN value, I will drop it

data1.dropna()
# Out:
#                BOROUGH Job Type           DOBRunDate
# 0            MANHATTAN       A2  12/12/2020 00:00:00
# 1        STATEN ISLAND       A2  12/12/2020 00:00:00
# 2             BROOKLYN       DM  06/18/2020 00:00:00
# 3             BROOKLYN       DM  06/18/2020 00:00:00
# 4             BROOKLYN       DM  06/18/2020 00:00:00
# ...                ...      ...                  ...
# 3747447         QUEENS       A2  06/01/2021 00:00:00
# 3747448       BROOKLYN       A2  06/01/2021 00:00:00
# 3747449       BROOKLYN       A1  06/01/2021 00:00:00
# 3747450         QUEENS       A1  06/01/2021 00:00:00
# 3747451       BROOKLYN       NB  06/01/2021 00:00:00
#
# [3747451 rows x 3 columns]

# %%
data1.to_csv('NY_Permitdata__cleaned.csv', index=False)
